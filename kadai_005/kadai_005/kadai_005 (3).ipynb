# %%
#上辺・下辺・高さに変数を代入
top= 10        #上辺(cm)
bottom = 20    #下辺(cm)
height = 5     #高さ(cm）

#台形の面積を計算して変数 area に代入
#（上辺 + 下辺）× 高さ ÷ ２
area = (top+bottom) * height / 2

print (str ( area ) + "㎠")
# Out:
# 75.0㎠
